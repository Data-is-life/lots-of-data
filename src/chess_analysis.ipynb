# %% [markdown]
# # Analysis:

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
from all_graphs import *
# from clean_chess_game_log import main_cleanup
# _, _, _ = main_cleanup('../data/dest.pgn')

# %%
df = get_graph_df('../data/use_for_analysis.csv')

# %% [markdown]
# ### My chances of winning are above 54% at:
# 6 AM, 9 AM, 10 AM, and 3 PM (7 AM and 1 PM are on the fringe)
#
# ### My chances of winning are below 46% at:
# 12 AM, 2 AM (0-3), 5 PM, 7 PM, and 10 PM
#
# Plus I shouldn't be playing after 3 PM. My chances are not looking so great :-/

# %%
graph_start_time(df)

# %% [markdown]
# ### My chances of winning are above 55% on:
# 3rd, 7th, 9th, 10th, 17th, and the 28th of the month
#
# ### My chances of winning are below 45% on:
# 4th, 8th, 25th, 27th, and the 30th of the month

# %%
graph_day_of_month(df)

# %% [markdown]
# ### The best day to play is:
# Thursday
#
# ### The worst day to play is:
# Friday

# %%
day_of_week(df)

# %% [markdown]
# ### My chances of winning increase by 4% if I castle King-side v. if I castle Queen-side

# %%
castled_or_not(df)

# %% [markdown]
# ### My chances of winning increase by 10%+ if opponent doesn't castle!!

# %%
opp_castled_or_not(df)

# %% [markdown]
# ### I need to work on 5 and 3 minute games

# %%
game_time(df)

# %% [markdown]
# ### My chances of winning are 5.5% higher if I play with white pieces

# %%
result_by_color(df)

# %% [markdown]
# ### I was stuck between 900 & 950 for a while

# %%
result_elo(df)

# %% [markdown]
# ### Second Graph == #PerfectNormalDistribution

# %%
opp_result_elo(df)

# %% [markdown]
# ### Negative difference means my ELO is less than opponents ELO
#
# I've played quite a few games against players with much higher ELO.

# %%
result_by_elo_diff(df)

# %% [markdown]
# ### I usually win by my opponent resigning or abandoning the game.
#
# Which is fairly typical once the other player knows the game is over
#
# Also, __By Rule__, __Stalemate__, __Repetition__, __By Agreement__, __Insufficient Material__ are all Draws

# %%
won_via(df)

# %% [markdown]
# ### Chances of winning are below 50% if number of moves are between 25 and 70 (Except for 50 moves game)
# ### I could pin the opponent in the first 20 moves or if the game goes over 80 moves
#
# Sprint or marathon, I'm winning!!

# %%
number_of_moves(df)

# %% [markdown]
# ### I usually castle by move # 11

# %%
move_num_castled(df)

# %%
opp_move_num_castled(df)

# %%
result_by_time_used(df)

# %%
result_by_opp_time_used(df)
