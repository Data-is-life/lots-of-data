# %% [markdown]
# # Analysis:

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
from all_graphs import *
# from clean_chess_game_log import main_cleanup
# _, _, _ = main_cleanup('../data/dest.pgn')

# %%
all_df = pd.read_csv('../data/main_with_all_info.csv')

# %%
all_df.columns
# Out:
# Index(['Unnamed: 0', 'date', 'result', 'white_elo', 'black_elo', 'game_time',
#        'end_time', 'num_moves', 'color', 'won_by', 'weekday', 'day',
#        'castled_on', 'opp_castled_on', 'castled', 'opp_castled', 'time_used',
#        'opp_time_used', 'start_time', 'opp_num_moves', 'avg_time',
#        'opp_avg_time', 'white_max_move', 'black_max_move', 'max_move',
#        'opp_max_move', 'post_elo', 'opp_post_elo', 'elo_delta', 'elo',
#        'opp_elo', 'diff'],
#       dtype='object')

# %%
all_df.drop(columns=['Unnamed: 0'], inplace=True)

# %%
df = get_graph_df('../data/use_for_analysis.csv')

# %% [markdown]
# ### My chances of winning are above 55% at:
# 6 AM, 10 AM, and 3 PM
#
# ### My chances of winning are below 45% at:
# 12 AM, 2 AM (0-3), 5 PM, 7 PM, and 10 PM

# %%
df = df.loc[1000:]

# %%
graph_start_time(df)

# %% [markdown]
# ### My chances of winning are above 55% on:
# 3rd, 7th, 9th, 10th, 17th, and the 28th of the month
#
# ### My chances of winning are below 45% on:
# 4th, 8th, 25th, 27th, and the 30th of the month

# %%
graph_day_of_month(df)

# %% [markdown]
# ### The best day to play is:
# Thursday
#
# ### The worst day to play is:
# Friday

# %%
day_of_week(df)

# %% [markdown]
# ### My chances of winning increase by 5% if I castle King-side v. if I castle Queen-side

# %%
castled_or_not(df)

# %% [markdown]
# ### My chances of winning increase by 14%+ if opponent doesn't castle!!

# %%
opp_castled_or_not(df)

# %%
game_time(df)

# %% [markdown]
# ### My chances of winning are 6% higher if I play with white pieces

# %%
result_by_color(df)

# %%
result_elo(df)

# %%
opp_result_elo(df)

# %%
result_by_elo_diff(df)

# %% [markdown]
# ### I usually win by my opponent resigning or abandoning the game. Which is fairly typical once the other player knows the game is over

# %%
won_via(df)

# %%
number_of_moves(df)

# %%
move_num_castled(df)

# %%
opp_move_num_castled(df)

# %%
result_by_time_used(df)

# %%
result_by_opp_time_used(df)
